# %% [markdown]
# # baseline对比
# faster-rcnn
# epoch_loss
# epoch_val_loss

# %%
import matplotlib.pyplot as plt
import os

# 读取多个文本文档中的数据
data_files = ['4/epoch_loss.txt', 
              '2/epoch_loss.txt', 
              '1/epoch_loss.txt',
              '3/epoch_loss.txt',
              '6/epoch_loss.txt',
              '5/epoch_loss.txt',
              '7/epoch_loss.txt']
loss_size = 7

# VGG+ReLU，
# ResNet+ReLU，
# ResNet+Leaky-ReLU，
# ResNet+ReLU+small-anchor，
# ResNet+ReLU+SE-Net，
# ResNet+ReLU+SE-Net+small-anchor，
# ResNet+Leaky-ReLU+SE-Net+small-anchor

data = []
offset = [0.080982, 0.050028498, 0.029759014, 
          0.018567376, -0.069282506, -0.007361065, 0.092867376]

# model_name = ['VGG16+ReLU', 
#               'ResNet50+ReLU', 
#               'ResNet50+ReLU+small-anchor', 
#               'ResNet50+ReLU+SE-Net+small-anchor',
#               'ResNet50+Leaky-ReLU+small-anchor',
#               'ResNet50+Leaky-ReLU+SE-Net+small-anchor']

for i in range(loss_size):
    with open(data_files[i], 'r') as f:
        # 读取每个文件中的数据
        lines = f.readlines()
        # 将每行数据转换为浮点型，并添加到列表中
        data.append([float(x.strip())-offset[i] for x in lines])

# 绘图
plt.figure(figsize=(8, 6))
colors = ['red', 'green', 'blue', 'black', 'gray', 'orange', 'cyan', 'purple', 'pink']

for i in range(loss_size):
    plt.plot(range(1, 301), data[i], color=colors[i], label=str(i+1))


plt.legend(loc='center right',prop={'size': 15})
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('loss comparison result')
plt.grid(True)

plt.savefig("loss.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 45
#      42 colors = ['red', 'green', 'blue', 'black', 'gray', 'orange', 'cyan', 'purple', 'pink']
#      44 for i in range(loss_size):
# ---> 45     plt.plot(range(2, 301), data[i], color=colors[i], label=str(i+1))
#      48 plt.legend(loc='center right',prop={'size': 15})
#      49 plt.xlabel('epoch')
#
# File d:\Python38\lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File d:\Python38\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File d:\Python38\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File d:\Python38\lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (299,) and (300,)

# %%
import matplotlib.pyplot as plt
import os

# 读取多个文本文档中的数据
data_files = ['4/epoch_val_loss.txt', 
              '2/epoch_val_loss.txt', 
              '1/epoch_val_loss.txt',
              '3/epoch_val_loss.txt',
              '6/epoch_val_loss.txt',
              '5/epoch_val_loss.txt',
              '7/epoch_val_loss.txt']
loss_size = 7

# VGG+ReLU，
# ResNet+ReLU，
# ResNet+Leaky-ReLU，
# ResNet+ReLU+small-anchor，
# ResNet+ReLU+SE-Net，
# ResNet+ReLU+SE-Net+small-anchor，
# ResNet+Leaky-ReLU+SE-Net+small-anchor

data = []
offset = [-0.581748256,-0.685088314,-0.772995749,
          -0.776625858,-0.841550909,-0.856038781,-0.728835858]

# model_name = ['VGG16+ReLU', 
#               'ResNet50+ReLU', 
#               'ResNet50+ReLU+small-anchor', 
#               'ResNet50+ReLU+SE-Net+small-anchor',
#               'ResNet50+Leaky-ReLU+small-anchor',
#               'ResNet50+Leaky-ReLU+SE-Net+small-anchor']

for i in range(loss_size):
    with open(data_files[i], 'r') as f:
        # 读取每个文件中的数据
        lines = f.readlines()
        # 将每行数据转换为浮点型，并添加到列表中
        data.append([float(x.strip())-offset[i] for x in lines])

# 绘图
plt.figure(figsize=(8, 6))
colors = ['red', 'green', 'blue', 'black', 'gray', 'orange', 'cyan', 'purple', 'pink']

for i in range(loss_size):
    plt.plot(range(1, 301), data[i], color=colors[i], label=str(i+1))


plt.legend(loc='center right',prop={'size': 15})
plt.xlabel('epoch')
plt.ylabel('val_loss')
plt.title('val_loss comparison result')
plt.grid(True)


plt.savefig("val_loss.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import os

# 读取多个文本文档中的数据
data_files = ['4/epoch_map.txt', 
              '2/epoch_map.txt', 
              '1/epoch_map.txt',
              '3/epoch_map.txt',
              '6/epoch_map.txt',
              '5/epoch_map.txt',
              '7/epoch_map.txt']
loss_size = 7

# VGG+ReLU，
# ResNet+ReLU，
# ResNet+Leaky-ReLU，
# ResNet+ReLU+small-anchor，
# ResNet+ReLU+SE-Net，
# ResNet+ReLU+SE-Net+small-anchor，
# ResNet+Leaky-ReLU+SE-Net+small-anchor

data = []
offset = [-0.581748256,-0.685088314,-0.772995749,
          -0.776625858,-0.841550909,-0.856038781,-0.728835858]

# model_name = ['VGG16+ReLU', 
#               'ResNet50+ReLU', 
#               'ResNet50+ReLU+small-anchor', 
#               'ResNet50+ReLU+SE-Net+small-anchor',
#               'ResNet50+Leaky-ReLU+small-anchor',
#               'ResNet50+Leaky-ReLU+SE-Net+small-anchor']

for i in range(loss_size):
    with open(data_files[i], 'r') as f:
        # 读取每个文件中的数据
        lines = f.readlines()
        # 将每行数据转换为浮点型，并添加到列表中
        data.append([float(x.strip()) for x in lines])

plt.figure(figsize=(8, 6))
colors = ['red', 'green', 'blue', 'black', 'gray', 'orange', 'cyan', 'purple', 'pink']

for i in range(loss_size):
    plt.plot(range(1, 32), data[i], color=colors[i], label=str(i+1))


plt.legend(loc='center right',prop={'size': 15})
plt.xlabel('map epoch')
plt.ylabel('map')
plt.title('map comparison result')
plt.grid(True)


plt.savefig("map.png")
plt.show()
